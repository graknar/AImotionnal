# %%
from Visualisation import plot_4D_dataframe
import numpy as np

# %%
# Définir une graine fixe pour le générateur de nombres aléatoires
# np.random.seed(42)

# Générer plusieurs ensembles de données aléatoires
data = np.random.normal(-1, 1, size=(10, 10, 10, 10))

# %%
fig = plot_4D_dataframe(data)
