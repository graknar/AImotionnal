# %%
import sys
sys.path.append('../')

from Function.EmotionalReader import get_emotions
from Function.Visualisation import plot_4D_dataframe, create_radar_chart

# %%
emotions, percentages = get_emotions("M cat is the epitome of my life")

# %%
create_radar_chart(emotions, percentages)
